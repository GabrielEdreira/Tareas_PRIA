# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielEdreira/Tareas_PRIA/blob/main/RNA_GabrielAntonioEdreiraGarcia/RNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Cargar los datos
df = pd.read_csv('./drive/MyDrive/Colab Notebooks/sensor_readings_24.csv', header=None)
df.columns = ['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9',
              's10', 's11', 's12', 's13', 's14', 's15', 's16',
              's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24', 'label']

# Visualizar la distribución de clases
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='label')
plt.title('Distribución de clases')
plt.xticks(rotation=45)
plt.show()

# Preprocesamiento
X = df.drop('label', axis=1)
y = df['label']

# Codificar las etiquetas
le = LabelEncoder()
y = le.fit_transform(y)
num_classes = len(le.classes_)
y_categorical = to_categorical(y)  # Convertir a one-hot encoding para Keras

# Dividir en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.3, random_state=42)

# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Crear modelo Keras
model = Sequential([
    Dense(100, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),  # Regularización
    Dense(50, activation='relu'),
    Dropout(0.2),
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping para evitar overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Entrenar el modelo
history = model.fit(X_train_scaled, y_train,
                    epochs=50,
                    batch_size=32,
                    validation_split=0.2,
                    callbacks=[early_stop],
                    verbose=1)

# Evaluación
y_pred_prob = model.predict(X_test_scaled)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

print("Accuracy:", accuracy_score(y_test_labels, y_pred))
print("\nClassification Report:\n", classification_report(y_test_labels, y_pred, target_names=le.classes_))

# Matriz de confusión
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_test_labels, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matriz de Confusión')
plt.xlabel('Predicho')
plt.ylabel('Verdadero')
plt.show()

# Gráfico de pérdida durante el entrenamiento
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Evolución de la Pérdida durante el Entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4610 - loss: 1.1778 - val_accuracy: 0.6976 - val_loss: 0.7610
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6866 - loss: 0.7672 - val_accuracy: 0.7565 - val_loss: 0.6361
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7215 - loss: 0.6539 - val_accuracy: 0.7749 - val_loss: 0.5704
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7632 - loss: 0.5910 - val_accuracy: 0.7945 - val_loss: 0.5236
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7959 - loss: 0.5299 - val_accuracy: 0.8037 - val_loss: 0.4862
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7892 - loss: 0.5251 - val_accuracy: 0.8259 - val_loss: 0.4552
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8079 - loss: 0.4758 - val_accuracy: 0.8351 - val_loss: 0.4388
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8215 - loss: 0.4519 - val_accuracy: 0.8390 - val_loss: 0.4158
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8374 - loss: 0.4312 - val_accuracy: 0.8403 - val_loss: 0.4047
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8420 - loss: 0.4108 - val_accuracy: 0.8586 - val_loss: 0.3852
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8430 - loss: 0.4144 - val_accuracy: 0.8665 - val_loss: 0.3696
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8565 - loss: 0.3811 - val_accuracy: 0.8639 - val_loss: 0.3610
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8619 - loss: 0.3744 - val_accuracy: 0.8639 - val_loss: 0.3648
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8691 - loss: 0.3350 - val_accuracy: 0.8704 - val_loss: 0.3473
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8613 - loss: 0.3699 - val_accuracy: 0.8730 - val_loss: 0.3367
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.3316 - val_accuracy: 0.8770 - val_loss: 0.3387
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8785 - loss: 0.3334 - val_accuracy: 0.8887 - val_loss: 0.3150
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8712 - loss: 0.3257 - val_accuracy: 0.8848 - val_loss: 0.3135
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8946 - loss: 0.2973 - val_accuracy: 0.8914 - val_loss: 0.3044
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8867 - loss: 0.2978 - val_accuracy: 0.8809 - val_loss: 0.3167
# Epoch 21/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8933 - loss: 0.2862 - val_accuracy: 0.8914 - val_loss: 0.2939
# Epoch 22/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8978 - loss: 0.2766 - val_accuracy: 0.8953 - val_loss: 0.2881
# Epoch 23/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9033 - loss: 0.2671 - val_accuracy: 0.8927 - val_loss: 0.2921
# Epoch 24/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8833 - loss: 0.2868 - val_accuracy: 0.8953 - val_loss: 0.2845
# Epoch 25/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9017 - loss: 0.2712 - val_accuracy: 0.9031 - val_loss: 0.2761
# Epoch 26/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9060 - loss: 0.2539 - val_accuracy: 0.8953 - val_loss: 0.2780
# Epoch 27/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8994 - loss: 0.2573 - val_accuracy: 0.8992 - val_loss: 0.2647
# Epoch 28/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9071 - loss: 0.2526 - val_accuracy: 0.9031 - val_loss: 0.2736
# Epoch 29/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9127 - loss: 0.2387 - val_accuracy: 0.9058 - val_loss: 0.2699
# Epoch 30/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9050 - loss: 0.2416 - val_accuracy: 0.9058 - val_loss: 0.2602
# Epoch 31/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9004 - loss: 0.2519 - val_accuracy: 0.9018 - val_loss: 0.2691
# Epoch 32/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9151 - loss: 0.2277 - val_accuracy: 0.9110 - val_loss: 0.2592
# Epoch 33/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.2253 - val_accuracy: 0.9110 - val_loss: 0.2514
# Epoch 34/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9239 - loss: 0.2083 - val_accuracy: 0.9097 - val_loss: 0.2488
# Epoch 35/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9158 - loss: 0.2171 - val_accuracy: 0.9084 - val_loss: 0.2502
# Epoch 36/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9213 - loss: 0.2123 - val_accuracy: 0.9149 - val_loss: 0.2454
# Epoch 37/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9320 - loss: 0.1980 - val_accuracy: 0.9097 - val_loss: 0.2517
# Epoch 38/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9273 - loss: 0.2067 - val_accuracy: 0.9084 - val_loss: 0.2559
# Epoch 39/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9286 - loss: 0.1968 - val_accuracy: 0.9215 - val_loss: 0.2476
# Epoch 40/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9312 - loss: 0.1853 - val_accuracy: 0.9136 - val_loss: 0.2440
# Epoch 41/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.1962 - val_accuracy: 0.9175 - val_loss: 0.2461
# Epoch 42/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9329 - loss: 0.1724 - val_accuracy: 0.9202 - val_loss: 0.2412
# Epoch 43/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9302 - loss: 0.1927 - val_accuracy: 0.9123 - val_loss: 0.2566
# Epoch 44/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9261 - loss: 0.1879 - val_accuracy: 0.9188 - val_loss: 0.2497
# Epoch 45/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9374 - loss: 0.1766 - val_accuracy: 0.9110 - val_loss: 0.2439
# Epoch 46/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9350 - loss: 0.1861 - val_accuracy: 0.9188 - val_loss: 0.2427
# Epoch 47/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9334 - loss: 0.1831 - val_accuracy: 0.9241 - val_loss: 0.2352
# Epoch 48/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9438 - loss: 0.1578 - val_accuracy: 0.9228 - val_loss: 0.2334
# Epoch 49/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9339 - loss: 0.1691 - val_accuracy: 0.9123 - val_loss: 0.2463
# Epoch 50/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9405 - loss: 0.1638 - val_accuracy: 0.9110 - val_loss: 0.2396
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.9077580940745266
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#      Move-Forward       0.89      0.91      0.90       671
#  Sharp-Right-Turn       0.93      0.94      0.94       620
#  Slight-Left-Turn       0.95      0.85      0.90        92
# Slight-Right-Turn       0.88      0.85      0.87       254
#
#          accuracy                           0.91      1637
#         macro avg       0.91      0.89      0.90      1637
#      weighted avg       0.91      0.91      0.91      1637

# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential, layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ---- 2. Data Loading ----
archive = "./drive/MyDrive/Colab Notebooks/Processed/"

# Load data with error handling
try:
    X_train = np.load(f'{archive}x_train.npy')
    y_train = np.load(f'{archive}y_train.npy')
    X_test = np.load(f'{archive}x_test.npy')
    y_test = np.load(f'{archive}y_test.npy')
except FileNotFoundError as e:
    print(f"Error loading files: {e}")
    raise

# ---- 3. Data Inspection ----
print("\n=== Data Shapes ===")
print(f"X_train: {X_train.shape} (dtype: {X_train.dtype})")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")

# ---- 4. Data Preprocessing ----
# Check if labels need encoding
if y_train.dtype == object or y_train.ndim == 1:
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    y_test = le.transform(y_test)
    y_train = tf.keras.utils.to_categorical(y_train)
    y_test = tf.keras.utils.to_categorical(y_test)

# Normalize audio features
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# ---- 5. Data Reshaping ----
# Fix shape mismatch: Flatten if needed
if X_train.ndim == 3:
    print("\nReshaping 3D data to 2D...")
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test = X_test.reshape(X_test.shape[0], -1)
    print(f"New shapes - X_train: {X_train.shape}, X_test: {X_test.shape}")

# Create validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train,
    test_size=0.2,
    stratify=y_train,
    random_state=42
)

# ---- 6. Model Architecture ----
def create_audio_model(input_shape, num_classes):
    model = Sequential([
        layers.Dense(256, activation='relu', input_shape=input_shape,
                    kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),

        layers.Dense(128, activation='relu',
                    kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.4),

        layers.Dense(64, activation='relu',
                    kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.Dense(num_classes, activation='softmax')
    ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    return model

# Initialize model
num_classes = y_train.shape[1]
model = create_audio_model((X_train.shape[1],), num_classes)
model.summary()

# ---- 7. Training Setup ----
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=10,
    min_lr=1e-6
)

# ---- 8. Model Training ----
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ---- 9. Evaluation ----
def evaluate_model(model, X_test, y_test):
    # Convert one-hot to labels
    y_true = np.argmax(y_test, axis=1)
    y_pred = np.argmax(model.predict(X_test), axis=1)

    # Metrics
    test_loss, test_acc, test_precision, test_recall = model.evaluate(X_test, y_test, verbose=0)
    print(f"\n{'Metric':<15} | {'Value':>10}")
    print("-" * 28)
    print(f"{'Accuracy':<15} | {test_acc:.4f}")
    print(f"{'Loss':<15} | {test_loss:.4f}")
    print(f"{'Precision':<15} | {test_precision:.4f}")
    print(f"{'Recall':<15} | {test_recall:.4f}")

    # Fix: Convert numerical classes to strings
    class_names = [str(cls) for cls in le.classes_]  # Convert to strings

    # Classification Report
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))  # Use string labels

    # Confusion Matrix (keep original labels)
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,  # Use string labels
                yticklabels=class_names)  # Use string labels
    plt.title('Confusion Matrix', fontsize=16)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# ---- 10. Training Visualization ----
def plot_training_history(history):
    plt.figure(figsize=(14, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Model Accuracy', fontsize=14)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Model Loss', fontsize=14)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# ---- 11. Model Saving ----
model.save(f'{archive}audio_classification_model.keras')
print(f"\nModel saved to {archive}audio_classification_model.keras")
# Out:
# === Data Shapes ===
# X_train: (20414, 32, 32) (dtype: float32)
# y_train: (20414,)
# X_test: (5104, 32, 32)
# y_test: (5104,)
#
# Reshaping 3D data to 2D...
# New shapes - X_train: (20414, 1024), X_test: (5104, 1024)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                     │ (None, 256)                 │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 305,994 (1.17 MB)
#  Trainable params: 305,098 (1.16 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.1570 - loss: 2.6797 - precision: 0.1774 - recall: 0.0316 - val_accuracy: 0.2650 - val_loss: 1.9990 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2654 - loss: 2.0222 - precision: 0.3935 - recall: 0.0565 - val_accuracy: 0.2378 - val_loss: 2.1982 - val_precision: 0.4744 - val_recall: 0.0431 - learning_rate: 0.0010
# Epoch 3/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3151 - loss: 1.8420 - precision: 0.4777 - recall: 0.0705 - val_accuracy: 0.2692 - val_loss: 1.9493 - val_precision: 0.3967 - val_recall: 0.1553 - learning_rate: 0.0010
# Epoch 4/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3362 - loss: 1.7677 - precision: 0.5734 - recall: 0.0971 - val_accuracy: 0.3603 - val_loss: 1.7293 - val_precision: 0.5902 - val_recall: 0.1002 - learning_rate: 0.0010
# Epoch 5/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3591 - loss: 1.7380 - precision: 0.6033 - recall: 0.1089 - val_accuracy: 0.3882 - val_loss: 1.6537 - val_precision: 0.7313 - val_recall: 0.1247 - learning_rate: 0.0010
# Epoch 6/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.3787 - loss: 1.6767 - precision: 0.6266 - recall: 0.1234 - val_accuracy: 0.3649 - val_loss: 1.6506 - val_precision: 0.6689 - val_recall: 0.1198 - learning_rate: 0.0010
# Epoch 7/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3854 - loss: 1.6589 - precision: 0.6258 - recall: 0.1257 - val_accuracy: 0.3662 - val_loss: 1.6795 - val_precision: 0.6726 - val_recall: 0.1212 - learning_rate: 0.0010
# Epoch 8/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3856 - loss: 1.6685 - precision: 0.6202 - recall: 0.1334 - val_accuracy: 0.4666 - val_loss: 1.4661 - val_precision: 0.7849 - val_recall: 0.1582 - learning_rate: 0.0010
# Epoch 9/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3935 - loss: 1.6346 - precision: 0.6446 - recall: 0.1447 - val_accuracy: 0.4352 - val_loss: 1.5595 - val_precision: 0.7547 - val_recall: 0.1590 - learning_rate: 0.0010
# Epoch 10/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4018 - loss: 1.6149 - precision: 0.6551 - recall: 0.1526 - val_accuracy: 0.4262 - val_loss: 1.5613 - val_precision: 0.6960 - val_recall: 0.1452 - learning_rate: 0.0010
# Epoch 11/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4015 - loss: 1.6192 - precision: 0.6561 - recall: 0.1553 - val_accuracy: 0.4506 - val_loss: 1.4985 - val_precision: 0.7174 - val_recall: 0.2449 - learning_rate: 0.0010
# Epoch 12/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4036 - loss: 1.5994 - precision: 0.6248 - recall: 0.1566 - val_accuracy: 0.4379 - val_loss: 1.5097 - val_precision: 0.6564 - val_recall: 0.2035 - learning_rate: 0.0010
# Epoch 13/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4161 - loss: 1.5816 - precision: 0.6279 - recall: 0.1652 - val_accuracy: 0.4609 - val_loss: 1.4549 - val_precision: 0.7444 - val_recall: 0.1969 - learning_rate: 0.0010
# Epoch 14/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.4153 - loss: 1.5869 - precision: 0.6454 - recall: 0.1695 - val_accuracy: 0.4879 - val_loss: 1.3805 - val_precision: 0.7714 - val_recall: 0.2297 - learning_rate: 0.0010
# Epoch 15/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4264 - loss: 1.5647 - precision: 0.6515 - recall: 0.1755 - val_accuracy: 0.4597 - val_loss: 1.4568 - val_precision: 0.7166 - val_recall: 0.2297 - learning_rate: 0.0010
# Epoch 16/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4274 - loss: 1.5490 - precision: 0.6572 - recall: 0.1851 - val_accuracy: 0.4920 - val_loss: 1.3807 - val_precision: 0.7716 - val_recall: 0.2292 - learning_rate: 0.0010
# Epoch 17/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4229 - loss: 1.5461 - precision: 0.6511 - recall: 0.1856 - val_accuracy: 0.3737 - val_loss: 1.6514 - val_precision: 0.5550 - val_recall: 0.1964 - learning_rate: 0.0010
# Epoch 18/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4325 - loss: 1.5525 - precision: 0.6609 - recall: 0.1939 - val_accuracy: 0.4744 - val_loss: 1.4133 - val_precision: 0.7054 - val_recall: 0.2469 - learning_rate: 0.0010
# Epoch 19/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4339 - loss: 1.5299 - precision: 0.6584 - recall: 0.1988 - val_accuracy: 0.4555 - val_loss: 1.4299 - val_precision: 0.6403 - val_recall: 0.2939 - learning_rate: 0.0010
# Epoch 20/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4349 - loss: 1.5536 - precision: 0.6524 - recall: 0.1952 - val_accuracy: 0.4734 - val_loss: 1.4097 - val_precision: 0.6981 - val_recall: 0.2469 - learning_rate: 0.0010
# Epoch 21/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4290 - loss: 1.5491 - precision: 0.6554 - recall: 0.1987 - val_accuracy: 0.4864 - val_loss: 1.4259 - val_precision: 0.7941 - val_recall: 0.2305 - learning_rate: 0.0010
# Epoch 22/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.4398 - loss: 1.5338 - precision: 0.6709 - recall: 0.1979 - val_accuracy: 0.4857 - val_loss: 1.3696 - val_precision: 0.6795 - val_recall: 0.2976 - learning_rate: 0.0010
# Epoch 23/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4412 - loss: 1.5213 - precision: 0.6720 - recall: 0.2066 - val_accuracy: 0.4969 - val_loss: 1.3586 - val_precision: 0.7868 - val_recall: 0.2422 - learning_rate: 0.0010
# Epoch 24/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4401 - loss: 1.5115 - precision: 0.6638 - recall: 0.2109 - val_accuracy: 0.4712 - val_loss: 1.4296 - val_precision: 0.6867 - val_recall: 0.2657 - learning_rate: 0.0010
# Epoch 25/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4443 - loss: 1.5059 - precision: 0.6727 - recall: 0.2152 - val_accuracy: 0.5104 - val_loss: 1.3251 - val_precision: 0.7201 - val_recall: 0.2880 - learning_rate: 0.0010
# Epoch 26/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4455 - loss: 1.5128 - precision: 0.6500 - recall: 0.2151 - val_accuracy: 0.5023 - val_loss: 1.3434 - val_precision: 0.7337 - val_recall: 0.2814 - learning_rate: 0.0010
# Epoch 27/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4340 - loss: 1.5301 - precision: 0.6583 - recall: 0.2084 - val_accuracy: 0.5082 - val_loss: 1.3230 - val_precision: 0.7372 - val_recall: 0.2961 - learning_rate: 0.0010
# Epoch 28/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4561 - loss: 1.4894 - precision: 0.6725 - recall: 0.2237 - val_accuracy: 0.4969 - val_loss: 1.3962 - val_precision: 0.7603 - val_recall: 0.2393 - learning_rate: 0.0010
# Epoch 29/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4440 - loss: 1.5101 - precision: 0.6581 - recall: 0.2157 - val_accuracy: 0.5058 - val_loss: 1.3330 - val_precision: 0.7747 - val_recall: 0.2493 - learning_rate: 0.0010
# Epoch 30/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4344 - loss: 1.5307 - precision: 0.6598 - recall: 0.2051 - val_accuracy: 0.4916 - val_loss: 1.3874 - val_precision: 0.7039 - val_recall: 0.2684 - learning_rate: 0.0010
# Epoch 31/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4372 - loss: 1.5228 - precision: 0.6533 - recall: 0.2033 - val_accuracy: 0.4952 - val_loss: 1.3519 - val_precision: 0.7115 - val_recall: 0.2900 - learning_rate: 0.0010
# Epoch 32/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.4455 - loss: 1.5025 - precision: 0.6561 - recall: 0.2169 - val_accuracy: 0.5028 - val_loss: 1.3711 - val_precision: 0.7132 - val_recall: 0.2753 - learning_rate: 0.0010
# Epoch 33/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4416 - loss: 1.5155 - precision: 0.6579 - recall: 0.2131 - val_accuracy: 0.4930 - val_loss: 1.3801 - val_precision: 0.7340 - val_recall: 0.2608 - learning_rate: 0.0010
# Epoch 34/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4401 - loss: 1.5180 - precision: 0.6601 - recall: 0.2087 - val_accuracy: 0.4960 - val_loss: 1.3812 - val_precision: 0.6933 - val_recall: 0.3057 - learning_rate: 0.0010
# Epoch 35/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4477 - loss: 1.4997 - precision: 0.6710 - recall: 0.2211 - val_accuracy: 0.5107 - val_loss: 1.3240 - val_precision: 0.7527 - val_recall: 0.2758 - learning_rate: 0.0010
# Epoch 36/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4520 - loss: 1.4924 - precision: 0.6756 - recall: 0.2227 - val_accuracy: 0.5099 - val_loss: 1.3175 - val_precision: 0.7548 - val_recall: 0.3008 - learning_rate: 0.0010
# Epoch 37/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4427 - loss: 1.5127 - precision: 0.6379 - recall: 0.2120 - val_accuracy: 0.4957 - val_loss: 1.3623 - val_precision: 0.7439 - val_recall: 0.2540 - learning_rate: 0.0010
# Epoch 38/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4483 - loss: 1.4998 - precision: 0.6615 - recall: 0.2211 - val_accuracy: 0.5040 - val_loss: 1.3401 - val_precision: 0.7150 - val_recall: 0.2826 - learning_rate: 0.0010
# Epoch 39/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4541 - loss: 1.4767 - precision: 0.6738 - recall: 0.2278 - val_accuracy: 0.4389 - val_loss: 1.4812 - val_precision: 0.6878 - val_recall: 0.1996 - learning_rate: 0.0010
# Epoch 40/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4476 - loss: 1.4950 - precision: 0.6674 - recall: 0.2244 - val_accuracy: 0.5263 - val_loss: 1.2930 - val_precision: 0.7595 - val_recall: 0.3032 - learning_rate: 0.0010
# Epoch 41/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4584 - loss: 1.4638 - precision: 0.6790 - recall: 0.2399 - val_accuracy: 0.4884 - val_loss: 1.4082 - val_precision: 0.7038 - val_recall: 0.2968 - learning_rate: 0.0010
# Epoch 42/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4554 - loss: 1.4763 - precision: 0.6814 - recall: 0.2381 - val_accuracy: 0.5271 - val_loss: 1.3065 - val_precision: 0.7983 - val_recall: 0.2812 - learning_rate: 0.0010
# Epoch 43/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4561 - loss: 1.4686 - precision: 0.6687 - recall: 0.2362 - val_accuracy: 0.5190 - val_loss: 1.3210 - val_precision: 0.8004 - val_recall: 0.2770 - learning_rate: 0.0010
# Epoch 44/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4570 - loss: 1.4773 - precision: 0.6761 - recall: 0.2355 - val_accuracy: 0.5028 - val_loss: 1.3444 - val_precision: 0.7814 - val_recall: 0.2836 - learning_rate: 0.0010
# Epoch 45/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4542 - loss: 1.4827 - precision: 0.6710 - recall: 0.2353 - val_accuracy: 0.5026 - val_loss: 1.3380 - val_precision: 0.7340 - val_recall: 0.2866 - learning_rate: 0.0010
# Epoch 46/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4620 - loss: 1.4684 - precision: 0.6751 - recall: 0.2357 - val_accuracy: 0.4896 - val_loss: 1.4287 - val_precision: 0.6394 - val_recall: 0.2949 - learning_rate: 0.0010
# Epoch 47/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4615 - loss: 1.4593 - precision: 0.6942 - recall: 0.2526 - val_accuracy: 0.5055 - val_loss: 1.3549 - val_precision: 0.7313 - val_recall: 0.2986 - learning_rate: 0.0010
# Epoch 48/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4539 - loss: 1.4777 - precision: 0.6658 - recall: 0.2349 - val_accuracy: 0.5376 - val_loss: 1.2735 - val_precision: 0.7552 - val_recall: 0.3316 - learning_rate: 0.0010
# Epoch 49/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4540 - loss: 1.4596 - precision: 0.6624 - recall: 0.2364 - val_accuracy: 0.5141 - val_loss: 1.3250 - val_precision: 0.7517 - val_recall: 0.2772 - learning_rate: 0.0010
# Epoch 50/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4592 - loss: 1.4717 - precision: 0.6808 - recall: 0.2361 - val_accuracy: 0.5293 - val_loss: 1.2844 - val_precision: 0.7594 - val_recall: 0.3216 - learning_rate: 0.0010
# Model saved to ./drive/MyDrive/Colab Notebooks/Processed/audio_classification_model.keras

# %%
from google.colab import drive
drive.mount('/content/drive')
